# %% [markdown]
# # Jump Start Notebook 1
# First thing we always do is to set up plotting environment and import some libraries
#
# REMEMBER: to run cells type **SHIFT-ENTER**

# %%
# %matplotlib notebook

# %%
from pylab import *
from lmfit import Model, report_fit
# Out:
# :0: FutureWarning: IPython widgets are experimental and may change in the future.

# %% [markdown]
# Let's read some data from *sample.csv*

# %%
data = loadtxt('sample.csv',delimiter=',')

# %%
data
# Out:
# array([[ 1. ,  2.2],
#        [ 2. ,  2.3],
#        [ 3. ,  2.5],
#        [ 4. ,  2.9],
#        [ 5. ,  3.7],
#        [ 6. ,  4.9],
#        [ 7. ,  6.3],
#        [ 8. ,  8.1]])

# %%
print(data)
# Out:
# [[ 1.   2.2]
#  [ 2.   2.3]
#  [ 3.   2.5]
#  [ 4.   2.9]
#  [ 5.   3.7]
#  [ 6.   4.9]
#  [ 7.   6.3]
#  [ 8.   8.1]]

# %% [markdown]
# Break data into x,y

# %%
x = data[:,0]
y = data[:,1]

# %%
print(x)
print(y)
# Out:
# [ 1.  2.  3.  4.  5.  6.  7.  8.]
# [ 2.2  2.3  2.5  2.9  3.7  4.9  6.3  8.1]

# %% [markdown]
# Let's plot data using [Matplotlib](http://matplotlib.org)

# %%
plot(x,y)
# Out:
# <img src="data:image/png;base64,...">
